# %% [markdown]
# **Autor:** Andrej Gajdoš  <br>
# *[Ústav matematických vied](https://www.upjs.sk/prirodovedecka-fakulta/ustav/umv/), [Prírodovedecká fakulta](https://www.upjs.sk/prirodovedecka-fakulta/), Univerzita Pavla Jozefa Šafárika v Košiciach,* <br>
# email: [andrej.gajdos@upjs.sk](mailto:andrej.gajdos@upjs.sk)
#
# ***
#
# **_Tento materiál vznikol za podpory grantu VVGS-2022-2412._**
#
# ***
#
# **<font size=6 color=blue> Python basics </font>**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
#
# **<font size=4 color=brown> Python </font>**
#
# * [Introduction to Python](jupyter_notebooks/IntroPython.ipynb?flush_cache=true)
#
#
# * [Python - assignments](jupyter_notebooks/IntroPythonAssignments.ipynb?flush_cache=true)

# %% [markdown]
# ---
#
# **<font size=4 color=brown> NumPy </font>**
#
# * [Introduction to NumPy](jupyter_notebooks/IntroNumpy.ipynb?flush_cache=true)
#
#
# * [NumPy - assignments](jupyter_notebooks/IntroNumpyAssignments.ipynb?flush_cache=true)

# %% [markdown]
# ---
#
# **<font size=4 color=brown> Matplotlib </font>**
#
# * [Introduction to Matplotlib](jupyter_notebooks/IntroMatplotlib.ipynb?flush_cache=true)
#
#
# * [Matplotlib - assignments](jupyter_notebooks/IntroMatplotlibAssignments.ipynb?flush_cache=true)

# %% [markdown]
# ---
#
# **<font size=4 color=brown> Pandas </font>**
#
# * [Introduction to Pandas](jupyter_notebooks/IntroPandas.ipynb?flush_cache=true)
#
#
# * [Pandas - assignments](jupyter_notebooks/IntroPandasAssignments.ipynb?flush_cache=true)

# %% [markdown]
# ---
#
# **<font size=4 color=brown> SciPy </font>**
#
# * [Introduction to SciPy](jupyter_notebooks/IntroSciPy.ipynb?flush_cache=true)
#
#
# * [SciPy - assignments](jupyter_notebooks/IntroSciPyAssignments.ipynb?flush_cache=true)

# %% [markdown]
# ---
#
# **<font size=4 color=brown> SymPy </font>**
#
# * [Introduction to SymPy](jupyter_notebooks/IntroSymPy.ipynb?flush_cache=true)
#
#
# * [SymPy - assignments](jupyter_notebooks/IntroSymPyAssignments.ipynb?flush_cache=true)

# %% [markdown]
# ---
#
# **<font size=4 color=brown> Fast Python </font>**
#
# * [Introduction to fast Python](jupyter_notebooks/IntroFastPython.ipynb?flush_cache=true)
#
#
# * [Fast Python - assignments](jupyter_notebooks/IntroFastPythonAssignments.ipynb?flush_cache=true)
